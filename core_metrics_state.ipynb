# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn'
# set display options to view all rows 
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("RDC_Inventory_Core_Metrics_State_History.csv")
df.head(50)
# Out:
#    month_date_yyyymm                 state state_id  median_listing_price  \
# 0             202206           connecticut       ct              524900.0
# 1             202206             wisconsin       wi              351250.0
# 2             202206                alaska       ak              409900.0
# 3             202206                hawaii       hi              871500.0
# 4             202206  district of columbia       dc              619950.0
# 5             202206               wyoming       wy              417200.0
# 6             202206              colorado       co              644500.0
# 7             202206                nevada       nv              522450.0
# 8             202206              nebraska       ne              314950.0
# 9             202206               alabama       al              323845.0
# 10            202206              kentucky       ky              278950.0
# 11            202206          south dakota       sd              344500.0
# ...

# %%
df.dtypes
# Out:
# month_date_yyyymm                           object
# state                                       object
# state_id                                    object
# median_listing_price                       float64
# median_listing_price_mm                    float64
# median_listing_price_yy                    float64
# active_listing_count                       float64
# active_listing_count_mm                    float64
# active_listing_count_yy                    float64
# median_days_on_market                      float64
# median_days_on_market_mm                   float64
# median_days_on_market_yy                   float64
# new_listing_count                          float64
# new_listing_count_mm                       float64
# new_listing_count_yy                       float64
# price_increased_count                      float64
# price_increased_count_mm                   float64
# price_increased_count_yy                   float64
# ...

# %%
# retrieve all rows that state = nc
north_carolina_df = df.loc[df['state_id'] == 'nc']
north_carolina_df
# Out:
#      month_date_yyyymm           state state_id  median_listing_price  \
# 24              202206  north carolina       nc              412500.0
# 100             202205  north carolina       nc              404950.0
# 117             202204  north carolina       nc              395000.0
# 192             202203  north carolina       nc              375644.0
# 212             202202  north carolina       nc              369900.0
# 261             202201  north carolina       nc              369500.0
# 326             202112  north carolina       nc              362504.0
# 372             202111  north carolina       nc              365214.0
# 455             202110  north carolina       nc              364544.0
# 489             202109  north carolina       nc              359000.0
# 521             202108  north carolina       nc              351352.0
# 605             202107  north carolina       nc              359236.0
# ...

# %%
# NaNs status
north_carolina_df.isnull().sum()
# Out:
# month_date_yyyymm                           0
# state                                       0
# state_id                                    0
# median_listing_price                        0
# median_listing_price_mm                    12
# median_listing_price_yy                    12
# active_listing_count                        0
# active_listing_count_mm                    12
# active_listing_count_yy                    12
# median_days_on_market                       0
# median_days_on_market_mm                   12
# median_days_on_market_yy                   12
# new_listing_count                           0
# new_listing_count_mm                       12
# new_listing_count_yy                       12
# price_increased_count                       0
# price_increased_count_mm                   12
# price_increased_count_yy                   12
# price_reduced_count                         0
# price_reduced_count_mm                     12
# ...

# %%
len(north_carolina_df)
# Out:
# 72

# %%
nc_drop_df = north_carolina_df.dropna()
nc_drop_df.isnull().sum()
# Out:
# month_date_yyyymm                          0
# state                                      0
# state_id                                   0
# median_listing_price                       0
# median_listing_price_mm                    0
# median_listing_price_yy                    0
# active_listing_count                       0
# active_listing_count_mm                    0
# active_listing_count_yy                    0
# median_days_on_market                      0
# median_days_on_market_mm                   0
# median_days_on_market_yy                   0
# new_listing_count                          0
# new_listing_count_mm                       0
# new_listing_count_yy                       0
# price_increased_count                      0
# price_increased_count_mm                   0
# price_increased_count_yy                   0
# price_reduced_count                        0
# price_reduced_count_mm                     0
# price_reduced_count_yy                     0
# ...

# %%
len(nc_drop_df)
# Out:
# 60
