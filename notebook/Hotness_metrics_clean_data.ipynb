# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn'
# set display options to view all rows 
pd.set_option('display.max_rows', None)

# %%
hotness_df = pd.read_csv("RDC_Inventory_Hotness_Metrics_Zip_History.csv")
hotness_df.head(20)
# Out:
# C:\Users\earth\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    month_date_yyyymm postal_code         zip_name  nielsen_hh_rank  \
# 0             202206       87015     edgewood, nm           8076.0
# 1             202206       15235   pittsburgh, pa           1591.0
# 2             202206       74501    mcalester, ok           3612.0
# 3             202206       71006       benton, la           8189.0
# 4             202206       37766  la follette, tn           6330.0
# 5             202206       97408       eugene, or           7973.0
# 6             202206       76634      clifton, tx          11216.0
# 7             202206       33511      brandon, fl            351.0
# 8             202206       75002        allen, tx            271.0
# ...

# %%
hotness_df.dtypes
# Out:
# month_date_yyyymm                         object
# postal_code                               object
# zip_name                                  object
# nielsen_hh_rank                          float64
# hotness_rank                             float64
# hotness_rank_mm                          float64
# hotness_rank_yy                          float64
# hotness_score                            float64
# supply_score                             float64
# demand_score                             float64
# median_days_on_market                    float64
# median_days_on_market_mm                 float64
# median_dom_mm_day                        float64
# median_days_on_market_yy                 float64
# median_dom_yy_day                        float64
# median_dom_vs_us                         float64
# ldp_unique_viewers_per_property_mm       float64
# ldp_unique_viewers_per_property_yy       float64
# ldp_unique_viewers_per_property_vs_us    float64
# ...

# %%
# number of null values each column
hotness_df.isnull().sum()
# Out:
# month_date_yyyymm                             0
# postal_code                                   0
# zip_name                                      1
# nielsen_hh_rank                               1
# hotness_rank                                  1
# hotness_rank_mm                          138615
# hotness_rank_yy                          138002
# hotness_score                                 1
# supply_score                                  1
# demand_score                                  1
# median_days_on_market                         1
# median_days_on_market_mm                 128442
# median_dom_mm_day                        128442
# median_days_on_market_yy                 128442
# median_dom_yy_day                        128442
# median_dom_vs_us                              1
# ldp_unique_viewers_per_property_mm       128442
# ldp_unique_viewers_per_property_yy       128442
# ldp_unique_viewers_per_property_vs_us         1
# median_listing_price                          1
# ...

# %%
len(hotness_df)
# Out:
# 596702

# %%
# drop nulls
hotness_drop_df = hotness_df.dropna()
hotness_drop_df.isnull().sum()
# Out:
# month_date_yyyymm                        0
# postal_code                              0
# zip_name                                 0
# nielsen_hh_rank                          0
# hotness_rank                             0
# hotness_rank_mm                          0
# hotness_rank_yy                          0
# hotness_score                            0
# supply_score                             0
# demand_score                             0
# median_days_on_market                    0
# median_days_on_market_mm                 0
# median_dom_mm_day                        0
# median_days_on_market_yy                 0
# median_dom_yy_day                        0
# median_dom_vs_us                         0
# ldp_unique_viewers_per_property_mm       0
# ldp_unique_viewers_per_property_yy       0
# ldp_unique_viewers_per_property_vs_us    0
# median_listing_price                     0
# median_listing_price_mm                  0
# median_listing_price_yy                  0
# ...

# %%
# rows after removing NaNs
len(hotness_drop_df)
# Out:
# 450618
