# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\earth\Desktop\final_project\filled_final_table.csv')
df.head()
# Out:
#       Date  Year     County  median_listing_price  active_listing_count  \
# 0  2022-06  2022   Alamance                382500                   298
# 1  2022-06  2022  Alexander                312450                    34
# 2  2022-06  2022  Alleghany                389000                    54
# 3  2022-06  2022      Anson                170000                    22
# 4  2022-06  2022       Ashe                485000                    76
#
#    median_days_on_market  new_listing_count  price_increased_count  \
# 0                     18                452                     12
# 1                     35                 28                      0
# 2                     39                 24                      0
# 3                     34                 16                      0
# 4                     31                 48                      0
#
#    price_reduced_count  median_square_feet  average_listing_price  \
# ...

# %%
df.loc[(df['County'] == 'Davie')]
# Out:
#          Date  Year County  median_listing_price  active_listing_count  \
# 29    2022-06  2022  Davie                255515                    79
# 129   2022-05  2022  Davie                232500                    66
# 229   2022-04  2022  Davie                225000                    50
# 329   2022-03  2022  Davie                215000                    55
# 428   2022-02  2022  Davie                247450                    52
# ...       ...   ...    ...                   ...                   ...
# 6725  2016-11  2016  Davie                240950                   286
# 6825  2016-10  2016  Davie                239900                   285
# 6925  2016-09  2016  Davie                243700                   299
# 7025  2016-08  2016  Davie                248000                   314
# 7125  2016-07  2016  Davie                245000                   314
#
#       median_days_on_market  new_listing_count  price_increased_count  \
# ...

# %%
df_new = df.drop(columns=['Number_of_Parks', 'Number_of_Schools'])
df_new.head()
# Out:
#       Date  Year     County  median_listing_price  active_listing_count  \
# 0  2022-06  2022   Alamance                382500                   298
# 1  2022-06  2022  Alexander                312450                    34
# 2  2022-06  2022  Alleghany                389000                    54
# 3  2022-06  2022      Anson                170000                    22
# 4  2022-06  2022       Ashe                485000                    76
#
#    median_days_on_market  new_listing_count  price_increased_count  \
# 0                     18                452                     12
# 1                     35                 28                      0
# 2                     39                 24                      0
# 3                     34                 16                      0
# 4                     31                 48                      0
#
#    price_reduced_count  median_square_feet  average_listing_price  \
# ...

# %%
df_new.loc[(df_new['County'] == 'Davie')]
# Out:
#          Date  Year County  median_listing_price  active_listing_count  \
# 29    2022-06  2022  Davie                255515                    79
# 129   2022-05  2022  Davie                232500                    66
# 229   2022-04  2022  Davie                225000                    50
# 329   2022-03  2022  Davie                215000                    55
# 428   2022-02  2022  Davie                247450                    52
# ...       ...   ...    ...                   ...                   ...
# 6725  2016-11  2016  Davie                240950                   286
# 6825  2016-10  2016  Davie                239900                   285
# 6925  2016-09  2016  Davie                243700                   299
# 7025  2016-08  2016  Davie                248000                   314
# 7125  2016-07  2016  Davie                245000                   314
#
#       median_days_on_market  new_listing_count  price_increased_count  \
# ...

# %%
df_count = pd.read_csv(r'C:\Users\earth\Desktop\class_folder\FinalProject\Resources\school_park_county_.csv')
df_count.head()
# Out:
#    zip_code  po_name  count_open_parks  year  all_school    countyname
# 0     27006  Advance                 0  2000           1  Davie County
# 1     27006  Advance                 0  2001           1  Davie County
# 2     27006  Advance                 0  2002           1  Davie County
# 3     27006  Advance                 0  2003           1  Davie County
# 4     27006  Advance                 0  2004           1  Davie County

# %%
df_count[['County', 'Drop']] = df_count['countyname'].str.rsplit(' ', n=1, expand=True) 
df_count.head()
# Out:
#    zip_code  po_name  count_open_parks  year  all_school    countyname County  \
# 0     27006  Advance                 0  2000           1  Davie County  Davie
# 1     27006  Advance                 0  2001           1  Davie County  Davie
# 2     27006  Advance                 0  2002           1  Davie County  Davie
# 3     27006  Advance                 0  2003           1  Davie County  Davie
# 4     27006  Advance                 0  2004           1  Davie County  Davie
#
#      Drop
# 0  County
# 1  County
# 2  County
# 3  County
# 4  County

# %%
df_count_new = df_count[['zip_code','po_name','count_open_parks','year',
                        'all_school','County']]
df_count_new.head()
# Out:
#    zip_code  po_name  count_open_parks  year  all_school County
# 0     27006  Advance                 0  2000           1  Davie
# 1     27006  Advance                 0  2001           1  Davie
# 2     27006  Advance                 0  2002           1  Davie
# 3     27006  Advance                 0  2003           1  Davie
# 4     27006  Advance                 0  2004           1  Davie

# %%
df_count_new1 =df_count_new[df_count_new['year'] >=2016]

# %%
 df_count_new1.loc[(df_count_new['County'] == 'Rowan')]
# Out:
#        zip_code      po_name  count_open_parks  year  all_school County
# 165       27013    Cleveland                 0  2016           2  Rowan
# 167       27013    Cleveland                 0  2017           3  Rowan
# 169       27013    Cleveland                 0  2018           3  Rowan
# 939       27054     Woodleaf                 0  2016           1  Rowan
# 940       27054     Woodleaf                 0  2017           1  Rowan
# 941       27054     Woodleaf                 0  2018           1  Rowan
# 10254     28023  China Grove                 5  2016           8  Rowan
# 10255     28023  China Grove                 5  2017           8  Rowan
# 10256     28023  China Grove                 5  2018           8  Rowan
# 10464     28036     Davidson                20  2016           4  Rowan
# 10468     28036     Davidson                20  2017           5  Rowan
# 10472     28036     Davidson                20  2018           5  Rowan
# ...

# %%
df_count_new2 =df_count_new1[df_count_new1['all_school'].sum()
# Out:
#   Input In [62]
#     df_count_new2 =df_count_new1[df_count_new1['all_school'].sum()
#                                                                   ^
# SyntaxError: unexpected EOF while parsing
