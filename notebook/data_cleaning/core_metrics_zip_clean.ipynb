# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn'
# set display options to view all rows 
pd.set_option('display.max_rows', None)

# %%
RDC_df = pd.read_csv("RDC_Inventory_Core_Metrics_Zip.csv")
RDC_df.head(20)
# Out:
# C:\Users\earth\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    month_date_yyyymm postal_code            zip_name  median_listing_price  \
# 0             202206       56448     fifty lakes, mn              549850.0
# 1             202206       39846          edison, ga              195900.0
# 2             202206       60632         chicago, il              281000.0
# 3             202206       58642         manning, nd              169000.0
# 4             202206       63359      middletown, mo              119900.0
# 5             202206       16656          irvona, pa               59900.0
# 6             202206       65026           eldon, mo              269900.0
# 7             202206       27305          milton, nc              595000.0
# ...

# %%
RDC_df.dtypes
# Out:
# month_date_yyyymm                           object
# postal_code                                 object
# zip_name                                    object
# median_listing_price                       float64
# median_listing_price_mm                    float64
# median_listing_price_yy                    float64
# active_listing_count                       float64
# active_listing_count_mm                    float64
# active_listing_count_yy                    float64
# median_days_on_market                      float64
# median_days_on_market_mm                   float64
# median_days_on_market_yy                   float64
# new_listing_count                          float64
# new_listing_count_mm                       float64
# new_listing_count_yy                       float64
# price_increased_count                      float64
# price_increased_count_mm                   float64
# price_increased_count_yy                   float64
# ...

# %%
# number of null values each column
RDC_df.isnull().sum()
# Out:
# month_date_yyyymm                              0
# postal_code                                    0
# zip_name                                       1
# median_listing_price                           1
# median_listing_price_mm                     1172
# median_listing_price_yy                     2131
# active_listing_count                           1
# active_listing_count_mm                     1699
# active_listing_count_yy                     2751
# median_days_on_market                          1
# median_days_on_market_mm                    1270
# median_days_on_market_yy                    2203
# new_listing_count                              1
# new_listing_count_mm                       10983
# new_listing_count_yy                       11360
# price_increased_count                          1
# price_increased_count_mm                   25428
# price_increased_count_yy                   24756
# price_reduced_count                            1
# ...

# %%
len(RDC_df)
# Out:
# 27659

# %%
# drop nulls
RDC_drop_df = RDC_df.dropna()
RDC_drop_df.isnull().sum()
# Out:
# month_date_yyyymm                          0
# postal_code                                0
# zip_name                                   0
# median_listing_price                       0
# median_listing_price_mm                    0
# median_listing_price_yy                    0
# active_listing_count                       0
# active_listing_count_mm                    0
# active_listing_count_yy                    0
# median_days_on_market                      0
# median_days_on_market_mm                   0
# median_days_on_market_yy                   0
# new_listing_count                          0
# new_listing_count_mm                       0
# new_listing_count_yy                       0
# price_increased_count                      0
# price_increased_count_mm                   0
# price_increased_count_yy                   0
# price_reduced_count                        0
# price_reduced_count_mm                     0
# price_reduced_count_yy                     0
# ...

# %%
# convert dtype
RDC_drop_df["pending_ratio_mm"] = RDC_drop_df["pending_ratio_mm"].astype(float)
RDC_drop_df["pending_ratio_yy"] = RDC_drop_df["pending_ratio_yy"].astype(float)

# %%
RDC_drop_df.head(50)
# Out:
#      month_date_yyyymm postal_code              zip_name  \
# 16              202206       30542    flowery branch, ga
# 24              202206       98092            auburn, wa
# 98              202206       33904        cape coral, fl
# 370             202206       97402            eugene, or
# 410             202206       31217             macon, ga
# 448             202206       36542       gulf shores, al
# 508             202206       32963        vero beach, fl
# 576             202206       97701              bend, or
# 612             202206       84065          riverton, ut
# 654             202206       50014              ames, ia
# 696             202206       33991        cape coral, fl
# 708             202206       97058        the dalles, or
# 750             202206       30188         woodstock, ga
# 764             202206       92020          el cajon, ca
# 768             202206       92532     lake elsinore, ca
# ...

# %%
# rows after removing NaNs
len(RDC_drop_df)
# Out:
# 1318

# %%
# check columns have converted
RDC_drop_df.dtypes
# Out:
# month_date_yyyymm                           object
# postal_code                                 object
# zip_name                                    object
# median_listing_price                       float64
# median_listing_price_mm                    float64
# median_listing_price_yy                    float64
# active_listing_count                       float64
# active_listing_count_mm                    float64
# active_listing_count_yy                    float64
# median_days_on_market                      float64
# median_days_on_market_mm                   float64
# median_days_on_market_yy                   float64
# new_listing_count                          float64
# new_listing_count_mm                       float64
# new_listing_count_yy                       float64
# price_increased_count                      float64
# price_increased_count_mm                   float64
# price_increased_count_yy                   float64
# ...

# %%
# activity of listings by zip codes
RDC_postal_df = RDC_df[["postal_code", "zip_name", "median_listing_price", "month_date_yyyymm", "active_listing_count", "total_listing_count"]].copy()
RDC_postal_df.head()
# Out:
#   postal_code         zip_name  median_listing_price month_date_yyyymm  \
# 0       56448  fifty lakes, mn              549850.0            202206
# 1       39846       edison, ga              195900.0            202206
# 2       60632      chicago, il              281000.0            202206
# 3       58642      manning, nd              169000.0            202206
# 4       63359   middletown, mo              119900.0            202206
#
#    active_listing_count  total_listing_count
# 0                   5.0                 10.0
# 1                   2.0                  2.0
# 2                  22.0                 68.0
# 3                   2.0                  2.0
# 4                   1.0                  1.0
