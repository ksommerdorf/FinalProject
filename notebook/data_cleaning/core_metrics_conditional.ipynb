# %%
import pandas as pd
import numpy as np

# %%
core_df = pd.read_csv("RDC_Inventory_Core_Metrics_State_History.csv")
core_df.head(20)
# Out:
#    month_date_yyyymm                 state state_id  median_listing_price  \
# 0             202206           connecticut       ct              524900.0
# 1             202206             wisconsin       wi              351250.0
# 2             202206                alaska       ak              409900.0
# 3             202206                hawaii       hi              871500.0
# 4             202206  district of columbia       dc              619950.0
# 5             202206               wyoming       wy              417200.0
# 6             202206              colorado       co              644500.0
# 7             202206                nevada       nv              522450.0
# 8             202206              nebraska       ne              314950.0
# 9             202206               alabama       al              323845.0
# 10            202206              kentucky       ky              278950.0
# 11            202206          south dakota       sd              344500.0
# ...

# %%
core_clean_df = core_df.dropna()
core_clean_df.isnull().sum()
# Out:
# month_date_yyyymm                          0
# state                                      0
# state_id                                   0
# median_listing_price                       0
# median_listing_price_mm                    0
# median_listing_price_yy                    0
# active_listing_count                       0
# active_listing_count_mm                    0
# active_listing_count_yy                    0
# median_days_on_market                      0
# median_days_on_market_mm                   0
# median_days_on_market_yy                   0
# new_listing_count                          0
# new_listing_count_mm                       0
# new_listing_count_yy                       0
# price_increased_count                      0
# price_increased_count_mm                   0
# price_increased_count_yy                   0
# price_reduced_count                        0
# price_reduced_count_mm                     0
# price_reduced_count_yy                     0
# ...

# %%
#core_clean_df['new_col'] = np.where(core_clean_df.groupby('state_id')['median_listing_price_mm'].transform(lambda x: (x>=0).all()), 'yes', 'no')
core_clean_df['Status'] = np.where(core_clean_df['median_listing_price_mm']>=0, 'yes', 'no')
# Out:
# C:\Users\earth\AppData\Local\Temp/ipykernel_8252/420282002.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   core_clean_df['Status'] = np.where(core_clean_df['median_listing_price_mm']>=0, 'yes', 'no')

# %%
core_clean_df.head(50)
# Out:
#    month_date_yyyymm                 state state_id  median_listing_price  \
# 0             202206           connecticut       ct              524900.0
# 1             202206             wisconsin       wi              351250.0
# 2             202206                alaska       ak              409900.0
# 3             202206                hawaii       hi              871500.0
# 4             202206  district of columbia       dc              619950.0
# 5             202206               wyoming       wy              417200.0
# 6             202206              colorado       co              644500.0
# 7             202206                nevada       nv              522450.0
# 8             202206              nebraska       ne              314950.0
# 9             202206               alabama       al              323845.0
# 10            202206              kentucky       ky              278950.0
# 11            202206          south dakota       sd              344500.0
# ...
